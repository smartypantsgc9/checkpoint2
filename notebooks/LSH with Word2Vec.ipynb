# %%
import pandas as pd
import re
import networkx as nx
import random

# %%
from gensim.models import word2vec
import numpy as np
from gensim.models import Phrases
import nltk
import nltk.data

# %%
from snapy import MinHash, LSH

# %% [markdown]
# ### Data

# %%
mesh=pd.read_csv('MESH.csv',usecols=['Preferred Label'])
mesh_ls = list(set(mesh['Preferred Label']))
mesh_terms = list(set([i.lower() for i in mesh_ls]))

# %%
text = 'reddit_data_names.txt'
filenames = open(text, 'r').read().split()

all_text = []
author_ids = []
for t in filenames:
    filepath = 'data/' + t + '.json'
    df = pd.read_json(filepath)
    all_text.extend(list(df['text']))
    author_ids.extend(list(df.index))

# %%
phrase_file1 = 'data/AutoPhrase_single-word.txt'
i = 0
autophrase_single = []
for r in open(phrase_file1, 'r').read().split():
    if i%2 == 1:
        autophrase_single.append(r)
    i += 1

phrase_file2 = 'data/AutoPhrase_multi-words.txt'
i = 0
autophrase_multi = []
for r in open(phrase_file2, 'r').read().split():
    if i%2 == 1:
        autophrase_multi.append(r)
    i += 1

# %% [markdown]
# ### Locality Similarity Hash

# %%
def make_content_all(search_terms, text, authors):
    #Initialize a dictionary
    content = dict()
    
    #Add search terms to dictionary with numbered key
    for i in range(len(search_terms)):
        if len(search_terms[i]) > 3:
            content[i] = search_terms[i].strip().lower()
                
    #Add text to dictionary with author as key
    for i in range(len(text)):
        key_n = 0
        for sentence in text[i].split():
            s=sentence.replace(',',' ').strip().lower()
            if len(s) > 5:
                key = authors[i] + "_" + str(key_n)
                content[key] = s
                key_n += 1
    return content

# %%
def create_lsh(content, n_permutations, n_gram):
    labels = content.keys()
    values = content.values()
    #Create MinHash object
    minhash = MinHash(values, n_gram=n_gram, permutations=n_permutations, hash_bits=64, seed=3)
    
    #Create LSH model
    lsh = LSH(minhash, labels,no_of_bands=n_permutations//2)
    del minhash
    return lsh


def add_similar_edges(graph,lsh, content, minjaccard):
    #For all items in content
    ls = {}
    for index, text in content.items():
        
        #If item is one of the search terms
        if type(index) == int:
            q = lsh.query(index, min_jaccard=minjaccard)
            
            #For all matches found
            for match in q:
                
                #If matched item is from the reddit text
                if type(match) != int:
                    author = match.split("_")[0]
                    term = content[match].strip('"').strip('.').strip('?')
                    #add term that are found in the reddit text to list
                    if author not in ls.keys():
                        ls[author] = [term]
                    else:
                        ls[author].append(term)
    for i in ls:
        ls[i]=list(set(ls[i]))
        total=len(ls[i])
        for n in range(total):
            for j in list(range(total))[n+1:]:
                graph.add_edge(ls[i][n],ls[i][j],author_id=i,)

# %% [markdown]
# ### Word2Vec Model

# %%
def text_to_list (text):
    cleaned_text = re.sub("[^a-zA-Z]", " ", text)
    words = cleaned_text.lower().split()
    
    return words

def text_to_sentences (text, tokenizer):
    raw_sentences = tokenizer.tokenize(text.strip())
    
    sentences=[]
    for s in raw_sentences:
        if len(s) > 0:
            sentences.append(text_to_list(s))
    return sentences

# %% [markdown]
# ### Main Code

# %%
#Necessary variables
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
num_feat = 100
num_neighbors = 5
model_name = "wv_reddit"


#Cleaning the text of the reddit data to a format that can be used in Word2Vec
sentences = []
for text in all_text:
    sentences += text_to_sentences(text, tokenizer)

#Building model
model = word2vec.Word2Vec(sentences, size=num_feat, window=num_neighbors, min_count=1)
model.save(model_name)

#Including bigrams to model
bigram = Phrases(sentences)
model = word2vec.Word2Vec(bigram[sentences], min_count=1)

#Training model on MESH terms
model.train([mesh_terms], total_examples=1, epochs=1)

# %%
#Defining a short list of terms from MESH.csv
short_mesh = mesh_terms[:len(mesh_terms)//5]

#Formatting the data to create LSH
content = make_content_all(short_mesh, all_text, author_ids)

# %%
#Creating an LSH model
lsh = create_lsh(content, n_permutations=100, n_gram=4)

# %%
#Going through queries, printing all mapped similar words,
#and the similarity based on Word2Vec model
for i in content:
    for n in lsh.query(i,min_jaccard=0.2):
        if (type(i)==int) & (type(n)!=int):
            term = content[n].strip('.').strip('?').strip('"')
            if (term in model.wv.vocab) & (content[i] in model.wv.vocab):
                print(content[i],' ------> ', term)
                print(model.wv.similarity(content[i], term))

# %%
#Building a graph
opioid_drugs = nx.DiGraph()
add_similar_edges(opioid_drugs, lsh, content, 0.2)

# %%
#Printing all edges with the author id
for i in opioid_drugs.edges:
    print(i,opioid_drugs.edges[i]['author_id'])
# Out:
# ('contact', 'stereotypical') gnjn1p
# ('contact', 'lawyer') gnjn1p
# ('contact', 'reduction') gnjn1p
# ('contact', 'porcelain') gnjn1p
# ('contact', 'information') gnjn1p
# ('contact', 'keeping') gnjn1p
# ('contact', 'injection') gnjn1p
# ('contact', 'diseases') gnjn1p
# ('contact', 'profiling') gnjn1p
# ('contact', 'question') gnjn1p
# ('contact', 'person') es0cs8
# ('contact', 'exchange') gnjn1p
# ('contact', 'financially') es0cs8
# ('contact', 'social') es0cs8
# ('contact', 'collected') es0cs8
# ('contact', 'substances') es0cs8
# ('contact', 'attribute') es0cs8
# ('contact', 'heroin') iidqgu
# ('contact', 'shoulders') iidqgu
# ('contact', 'fingers') iidqgu
# ('contact', 'physical') iidqgu
# ('contact', 'living') iidqgu
# ('contact', 'smoking') iidqgu
# ('contact', 'parents') iidqgu
# ('contact', 'substance') iidqgu
# ('contact', 'cocaine') iidqgu
# ('contact', 'sweat') iidqgu
# ('contact', 'string') iidqgu
# ('contact', 'another') iidqgu
# ('contact', 'asleep') iidqgu
# ('contact', 'animals') e3dwnz
# ('contact', 'practitioner') e3dwnz
# ('contact', 'relating') e3dwnz
# ('contact', 'invitation') e3dwnz
# ('stereotypical', 'lawyer') gnjn1p
# ('stereotypical', 'reduction') gnjn1p
# ('stereotypical', 'porcelain') gnjn1p
# ('stereotypical', 'information') gnjn1p
# ('stereotypical', 'keeping') gnjn1p
# ('stereotypical', 'injection') gnjn1p
# ('stereotypical', 'diseases') gnjn1p
# ('stereotypical', 'profiling') gnjn1p
# ('stereotypical', 'question') gnjn1p
# ('stereotypical', 'person') gnjn1p
# ('stereotypical', 'exchange') gnjn1p
# ('lawyer', 'reduction') gnjn1p
# ('lawyer', 'porcelain') gnjn1p
# ('lawyer', 'information') gnjn1p
# ('lawyer', 'keeping') gnjn1p
# ('lawyer', 'injection') gnjn1p
# ('lawyer', 'diseases') gnjn1p
# ('lawyer', 'profiling') gnjn1p
# ('lawyer', 'question') gnjn1p
# ('lawyer', 'person') gnjn1p
# ('lawyer', 'exchange') gnjn1p
# ('reduction', 'porcelain') gnjn1p
# ('reduction', 'information') hsvt5e
# ('reduction', 'keeping') gnjn1p
# ('reduction', 'injection') gnjn1p
# ('reduction', 'diseases') gnjn1p
# ('reduction', 'profiling') gnjn1p
# ('reduction', 'question') ibsqeg
# ('reduction', 'person') gnjn1p
# ('reduction', 'exchange') gnjn1p
# ('reduction', 'healthy') hffmkt
# ('reduction', 'should') f94zw0
# ('reduction', 'reading') hffmkt
# ('reduction', 'nicotine') gydy9x
# ('reduction', '^governments') hsvt5e
# ('reduction', 'spreading') hsvt5e
# ('reduction', 'questions') f94zw0
# ('reduction', '[relevant') hsvt5e
# ('reduction', 'smoking') gydy9x
# ('reduction', 'herbal') gydy9x
# ('reduction', 'parents') gydy9x
# ('reduction', 'substance') gydy9x
# ('reduction', 'condition') gydy9x
# ('reduction', 'clarification') gydy9x
# ('reduction', 'boredom') iklfj9
# ('reduction', 'introduce') fwscib
# ('reduction', 'addiction') hs7wy5
# ('reduction', 'animals left') fwscib
# ('reduction', 'provision**') ibsqeg
# ('reduction', 'reduction*') ibsqeg
# ('reduction', 'substances') ibsqeg
# ('reduction', 'patient') hs7wy5
# ('reduction', 'compounding') hs7wy5
# ('reduction', 'patiently') hs7wy5
# ('reduction', 'amphetamines') hs7wy5
# ('reduction', 'personality') hs7wy5
# ('reduction', 'effect') f94zw0
# ('reduction', 'complications') f94zw0
# ('reduction', 'mention') f94zw0
# ('reduction', 'temperature') f94zw0
# ('reduction', '“should') f94zw0
# ('reduction', 'alcohol') f94zw0
# ('reduction', 'research') f94zw0
# ('reduction', 'practice') f94zw0
# ('porcelain', 'information') gnjn1p
# ('porcelain', 'keeping') gnjn1p
# ('porcelain', 'injection') gnjn1p
# ('porcelain', 'diseases') gnjn1p
# ('porcelain', 'profiling') gnjn1p
# ('porcelain', 'question') gnjn1p
# ('porcelain', 'person') gnjn1p
# ('porcelain', 'exchange') gnjn1p
# ('information', 'keeping') gnjn1p
# ('information', 'injection') gnjn1p
# ('information', 'diseases') gnjn1p
# ('information', 'profiling') gnjn1p
# ('information', 'question') hxd5w8
# ('information', 'person') ev9s9x
# ('information', 'exchange') gnjn1p
# ('information', '^governments') hsvt5e
# ('information', 'spreading') j5sywq
# ('information', 'questions') j5sywq
# ('information', '[relevant') hsvt5e
# ('information', 'decision') iklfj9
# ('information', 'reduction') iklfj9
# ('information', 'boredom') iklfj9
# ('information', 'personal') h89mcw
# ('information', 'sections:') h89mcw
# ('information', 'communication') ev9s9x
# ('information', 'living') fnsaq1
# ('information', 'smoking') ev9s9x
# ('information', 'thefts') ev9s9x
# ('information', 'better') f2b4lh
# ('information', 'coming') ev9s9x
# ('information', 'nicotine') fnsaq1
# ('information', 'security') ev9s9x
# ('information', 'solution') ev9s9x
# ('information', 'another') ev9s9x
# ('information', 'discussion') j5sywq
# ('information', 'substance') j5sywq
# ('information', 'should') fnsaq1
# ('information', 'research') f2b4lh
# ('information', 'technically') j5sywq
# ('information', 'including') j2j18k
# ('information', 'reports') hxd5w8
# ('information', 'benefits') j2j18k
# ('information', 'chemicals;') j2j18k
# ('information', 'program') j2j18k
# ('information', 'projects') j2j18k
# ('information', 'substances') fnsaq1
# ('information', 'millions') j2j18k
# ('information', 'recovery') f2b4lh
# ('information', 'melatonin') fnsaq1
# ('information', 'vitamins') fnsaq1
# ('information', 'direct') iah1j3
# ('information', 'pupils') hxd5w8
# ('information', 'cannabis') hxd5w8
# ('keeping', 'injection') i2k0ab
# ('keeping', 'diseases') gnjn1p
# ('keeping', 'profiling') gnjn1p
# ('keeping', 'question') gnjn1p
# ('keeping', 'person') i2k0ab
# ('keeping', 'exchange') gnjn1p
# ('keeping', 'statistically') i2k0ab
# ('keeping', 'blood') i2k0ab
# ('keeping', 'physical') i2k0ab
# ('keeping', 'vision') i2k0ab
# ('keeping', 'background') i2k0ab
# ('keeping', 'diacetylmorphine') i2k0ab
# ('keeping', 'production') i2k0ab
# ('keeping', 'morphine') i2k0ab
# ('keeping', "heroin's") i2k0ab
# ('keeping', 'reading') i2k0ab
# ('keeping', 'realization') i2k0ab
# ('keeping', 'survival') i2k0ab
# ('keeping', 'nausea') i2k0ab
# ('keeping', 'jading') i2k0ab
# ('keeping', 'sickness') i2k0ab
# ('keeping', 'congestion') i2k0ab
# ('keeping', 'addiction') i2k0ab
# ('keeping', 'concentration') i2k0ab
# ('keeping', 'compounds') i2k0ab
# ('keeping', 'effect') i2k0ab
# ('keeping', 'diarrhea') i2k0ab
# ('keeping', 'psychological') i2k0ab
# ('keeping', 'sleeping') i2k0ab
# ('keeping', "person's") i2k0ab
# ('keeping', 'respiratory') i2k0ab
# ('keeping', 'injuries') i2k0ab
# ('keeping', 'analgesic') i2k0ab
# ('keeping', 'gastrointestinal') i2k0ab
# ('keeping', 'receptors') i2k0ab
# ('keeping', 'sweats') i2k0ab
# ('keeping', 'substance') i2k0ab
# ('keeping', 'development') i2k0ab
# ('keeping', 'psychologically') i2k0ab
# ('keeping', 'recreational') i2k0ab
# ('keeping', 'rejuvenated') j4zquq
# ('keeping', 'caring') j4zquq
# ('injection', 'diseases') gnjn1p
# ('injection', 'profiling') gnjn1p
# ('injection', 'question') gnjn1p
# ('injection', 'person') i2k0ab
# ('injection', 'exchange') gnjn1p
# ('injection', 'statistically') i2k0ab
# ('injection', 'blood') i2k0ab
# ('injection', 'physical') i2k0ab
# ('injection', 'vision') i2k0ab
# ('injection', 'background') i2k0ab
# ('injection', 'diacetylmorphine') i2k0ab
# ('injection', 'production') i2k0ab
# ('injection', 'morphine') i2k0ab
# ('injection', "heroin's") i2k0ab
# ('injection', 'reading') i2k0ab
# ('injection', 'realization') i2k0ab
# ('injection', 'survival') i2k0ab
# ('injection', 'nausea') i2k0ab
# ('injection', 'jading') i2k0ab
# ('injection', 'sickness') i2k0ab
# ('injection', 'congestion') i2k0ab
# ('injection', 'addiction') i2k0ab
# ('injection', 'concentration') i2k0ab
# ('injection', 'compounds') i2k0ab
# ('injection', 'effect') i2k0ab
# ('injection', 'diarrhea') i2k0ab
# ('injection', 'psychological') i2k0ab
# ('injection', 'sleeping') i2k0ab
# ('injection', "person's") i2k0ab
# ('injection', 'respiratory') i2k0ab
# ('injection', 'injuries') i2k0ab
# ('injection', 'analgesic') i2k0ab
# ('injection', 'gastrointestinal') i2k0ab
# ('injection', 'receptors') i2k0ab
# ('injection', 'sweats') i2k0ab
# ('injection', 'substance') i2k0ab
# ('injection', 'development') i2k0ab
# ('injection', 'psychologically') i2k0ab
# ('injection', 'recreational') i2k0ab
# ('diseases', 'profiling') gnjn1p
# ('diseases', 'question') gnjn1p
# ('diseases', 'person') gnjn1p
# ('diseases', 'exchange') gnjn1p
# ('profiling', 'question') gnjn1p
# ('profiling', 'person') gnjn1p
# ('profiling', 'exchange') gnjn1p
# ('question', 'person') hehv9f
# ('question', 'exchange') gnjn1p
# ('question', 'blood') e427qz
# ('question', 'asleep') e427qz
# ('question', 'reduction*') ibsqeg
# ('question', 'substances') ev18s6
# ('question', 'should') hehv9f
# ('question', 'religious') ev18s6
# ('question', 'alcohol') ev18s6
# ('question', 'questions') ev18s6
# ('question', 'another') e2hanq
# ('question', 'coming') hehv9f
# ('question', 'affect') hehv9f
# ('question', 'research') j5sywq
# ('question', 'technically') j5sywq
# ('question', 'caffeine') icia42
# ('question', 'cannabis') hxd5w8
# ('question', 'pretend') ea7uy5
# ('person', 'exchange') gnjn1p
# ('person', 'codeine') iwc5jn
# ('person', 'wandering') iwc5jn
# ('person', 'social') iwc5jn
# ('person', 'recreationally') iwc5jn
# ('person', 'development') i2k0ab
# ('person', 'research') iwc5jn
# ('person', 'bloodshot') iwc5jn
# ('person', 'asleep') iwc5jn
# ('person', "person's") i2k0ab
# ('person', 'respiratory') i2k0ab
# ('person', 'injuries') i2k0ab
# ('person', 'analgesic') i2k0ab
# ('person', 'gastrointestinal') i2k0ab
# ('person', 'receptors') i2k0ab
# ('person', 'sweats') i2k0ab
# ('person', 'substance') i2k0ab
# ('person', 'psychologically') i2k0ab
# ('person', 'recreational') i2k0ab
# ('person', 'university') dv5gy3
# ('person', 'another') ev9s9x
# ('person', 'attribute') es0cs8
# ('person', 'living') etscvd
# ('person', 'moderation') etscvd
# ('drinking', 'ingest') iwc5jn
# ('drinking', 'hydrated') iwc5jn
# ('drinking', 'background') iwc5jn
# ('drinking', 'should') dz5ye5
# ('drinking', 'coming') fblflt
# ('drinking', 'tramadol') iwc5jn
# ('drinking', 'rolling') iwc5jn
# ('drinking', 'shoulders') iwc5jn
# ('drinking', 'similar') iwc5jn
# ('drinking', 'ibuprofen') iwc5jn
# ('drinking', 'concentration') iwc5jn
# ('drinking', 'preparation:') iwc5jn
# ('drinking', 'cardinal') iwc5jn
# ('drinking', 'person') iwc5jn
# ('drinking', 'codeine') iwc5jn
# ('drinking', 'wandering') iwc5jn
# ('drinking', 'social') dz5ye5
# ('drinking', 'recreationally') iwc5jn
# ('drinking', 'development') iwc5jn
# ('drinking', 'research') iwc5jn
# ('drinking', 'bloodshot') iwc5jn
# ('drinking', 'asleep') e427qz
# ('drinking', 'maximum') e427qz
# ('drinking', 'geometry') e427qz
# ('drinking', 'environment') e427qz
# ('drinking', 'better') fblflt
# ('drinking', 'cigarette') e427qz
# ('drinking', 'alcohol') dz5ye5
# ('drinking', 'particles') e427qz
# ('drinking', 'silver') e427qz
# ('drinking', 'caffeine') dz5ye5
# ('drinking', 'phantom') e427qz
# ('drinking', 'included') e427qz
# ('drinking', 'sleep') gm50du
# ('drinking', 'spiders') e427qz
# ('drinking', 'visualy') e427qz
# ('drinking', 'hallucination') e427qz
# ('drinking', 'substance') dz5ye5
# ('drinking', 'cigarettes') e427qz
# ('drinking', 'boring') e427qz
# ('drinking', 'letters') e427qz
# ('drinking', 'valerian') e427qz
# ('drinking', 'question') e427qz
# ('drinking', 'blood') e427qz
# ('drinking', 'magnesium') fblflt
# ('drinking', 'rushing') fblflt
# ('drinking', 'pupils') fblflt
# ('drinking', 'constipated') fblflt
# ('drinking', 'diarrhea') fblflt
# ('drinking', 'tolerance') fblflt
# ('drinking', 'smoking') gm50du
# ('drinking', 'questions') ij4p71
# ('drinking', 'healthy') dz5ye5
# ('drinking', 'shifting') dz5ye5
# ('drinking', 'popular') dz5ye5
# ('drinking', 'chemical') dz5ye5
# ('drinking', 'salvia') dz5ye5
# ('drinking', 'animals') dz5ye5
# ('drinking', 'condition') dz5ye5
# ('drinking', 'smokers') dz5ye5
# ('drinking', 'pretend') dz5ye5
# ('drinking', 'effect') dz5ye5
# ('drinking', 'consciousness') dz5ye5
# ('drinking', 'relaxation') dz5ye5
# ('drinking', 'another') dz5ye5
# ('ingest', 'hydrated') iwc5jn
# ('ingest', 'background') iwc5jn
# ('ingest', 'should') iwc5jn
# ('ingest', 'coming') iwc5jn
# ('ingest', 'tramadol') iwc5jn
# ('ingest', 'rolling') iwc5jn
# ('ingest', 'shoulders') iwc5jn
# ('ingest', 'similar') iwc5jn
# ('ingest', 'ibuprofen') iwc5jn
# ('ingest', 'concentration') iwc5jn
# ('ingest', 'preparation:') iwc5jn
# ('ingest', 'cardinal') iwc5jn
# ('ingest', 'person') iwc5jn
# ('ingest', 'codeine') iwc5jn
# ('ingest', 'wandering') iwc5jn
# ('ingest', 'social') iwc5jn
# ('ingest', 'recreationally') iwc5jn
# ('ingest', 'development') iwc5jn
# ('ingest', 'research') iwc5jn
# ('ingest', 'bloodshot') iwc5jn
# ('ingest', 'asleep') iwc5jn
# ('hydrated', 'background') iwc5jn
# ('hydrated', 'should') iwc5jn
# ('hydrated', 'coming') iwc5jn
# ('hydrated', 'tramadol') iwc5jn
# ('hydrated', 'rolling') iwc5jn
# ('hydrated', 'shoulders') iwc5jn
# ('hydrated', 'similar') iwc5jn
# ('hydrated', 'ibuprofen') iwc5jn
# ('hydrated', 'concentration') iwc5jn
# ('hydrated', 'preparation:') iwc5jn
# ('hydrated', 'cardinal') iwc5jn
# ('hydrated', 'person') iwc5jn
# ('hydrated', 'codeine') iwc5jn
# ('hydrated', 'wandering') iwc5jn
# ('hydrated', 'social') iwc5jn
# ('hydrated', 'recreationally') iwc5jn
# ('hydrated', 'development') iwc5jn
# ('hydrated', 'research') iwc5jn
# ('hydrated', 'bloodshot') iwc5jn
# ('hydrated', 'asleep') iwc5jn
# ('background', 'should') iwc5jn
# ('background', 'coming') ev9s9x
# ('background', 'tramadol') iwc5jn
# ('background', 'rolling') iwc5jn
# ('background', 'shoulders') iwc5jn
# ('background', 'similar') iwc5jn
# ('background', 'ibuprofen') iwc5jn
# ('background', 'concentration') i2k0ab
# ('background', 'preparation:') iwc5jn
# ('background', 'cardinal') iwc5jn
# ('background', 'person') ev9s9x
# ('background', 'codeine') iwc5jn
# ('background', 'wandering') iwc5jn
# ('background', 'social') iwc5jn
# ('background', 'recreationally') iwc5jn
# ('background', 'development') i2k0ab
# ('background', 'research') iwc5jn
# ('background', 'bloodshot') iwc5jn
# ('background', 'asleep') iwc5jn
# ('background', 'diacetylmorphine') i2k0ab
# ('background', 'production') i2k0ab
# ('background', 'morphine') i2k0ab
# ('background', "heroin's") i2k0ab
# ('background', 'reading') i2k0ab
# ('background', 'realization') i2k0ab
# ('background', 'survival') i2k0ab
# ('background', 'nausea') i2k0ab
# ('background', 'jading') i2k0ab
# ('background', 'sickness') i2k0ab
# ('background', 'congestion') i2k0ab
# ('background', 'addiction') i2k0ab
# ('background', 'compounds') i2k0ab
# ('background', 'effect') i2k0ab
# ('background', 'diarrhea') i2k0ab
# ('background', 'psychological') i2k0ab
# ('background', 'sleeping') i2k0ab
# ('background', "person's") i2k0ab
# ('background', 'respiratory') i2k0ab
# ('background', 'injuries') i2k0ab
# ('background', 'analgesic') i2k0ab
# ('background', 'gastrointestinal') i2k0ab
# ('background', 'receptors') i2k0ab
# ('background', 'sweats') i2k0ab
# ('background', 'substance') i2k0ab
# ('background', 'psychologically') i2k0ab
# ('background', 'recreational') i2k0ab
# ('background', 'information') ev9s9x
# ('background', 'communication') ev9s9x
# ('background', 'living') ev9s9x
# ('background', 'smoking') ev9s9x
# ('background', 'thefts') ev9s9x
# ('background', 'better') ev9s9x
# ('background', 'nicotine') ev9s9x
# ('background', 'security') ev9s9x
# ('background', 'solution') ev9s9x
# ('background', 'another') ev9s9x
# ('should', 'coming') e2hanq
# ('should', 'tramadol') iwc5jn
# ('should', 'rolling') iwc5jn
# ('should', 'shoulders') iwc5jn
# ('should', 'similar') iwc5jn
# ('should', 'ibuprofen') iwc5jn
# ('should', 'concentration') iwc5jn
# ('should', 'preparation:') iwc5jn
# ('should', 'cardinal') iwc5jn
# ('should', 'person') hehv9f
# ('should', 'codeine') iwc5jn
# ('should', 'wandering') iwc5jn
# ('should', 'social') dz5ye5
# ('should', 'recreationally') gid5ro
# ('should', 'development') iwc5jn
# ('should', 'research') j5sywq
# ('should', 'bloodshot') iwc5jn
# ('should', 'asleep') gid5ro
# ('should', 'reading') gid5ro
# ('should', 'nicotine') fnsaq1
# ('should', 'animals left') fwscib
# ('should', 'question') icia42
# ('should', 'reduction*') ibsqeg
# ('should', 'substances') fnsaq1
# ('should', 'patiently') hs7wy5
# ('should', 'amphetamines') hs7wy5
# ('should', 'personality') i138nq
# ('should', 'questions') ev18s6
# ('coming', 'morale') e2hanq
# ('coming', 'temperature') e2hanq
# ('coming', 'imagination') e2hanq
# ('coming', 'gelatin') idv46x
# ('coming', 'practice') idv46x
# ('coming', 'vividly') idv46x
# ('tramadol', 'rolling') iwc5jn
# ('tramadol', 'shoulders') iwc5jn
# ('tramadol', 'similar') iwc5jn
# ('tramadol', 'ibuprofen') iwc5jn
# ('tramadol', 'concentration') iwc5jn
# ('tramadol', 'preparation:') iwc5jn
# ('tramadol', 'cardinal') iwc5jn
# ('tramadol', 'person') iwc5jn
# ('tramadol', 'codeine') iwc5jn
# ('tramadol', 'wandering') iwc5jn
# ('tramadol', 'social') iwc5jn
# ('tramadol', 'recreationally') iwc5jn
# ('tramadol', 'development') iwc5jn
# ('tramadol', 'research') iwc5jn
# ('tramadol', 'bloodshot') iwc5jn
# ('tramadol', 'asleep') iwc5jn
# ('rolling', 'shoulders') iwc5jn
# ('rolling', 'similar') iwc5jn
# ('rolling', 'ibuprofen') iwc5jn
# ('rolling', 'concentration') iwc5jn
# ('rolling', 'preparation:') iwc5jn
# ('rolling', 'cardinal') iwc5jn
# ('rolling', 'person') iwc5jn
# ('rolling', 'codeine') iwc5jn
# ('rolling', 'wandering') iwc5jn
# ('rolling', 'social') iwc5jn
# ('rolling', 'recreationally') iwc5jn
# ('rolling', 'development') iwc5jn
# ('rolling', 'research') iwc5jn
# ('rolling', 'bloodshot') iwc5jn
# ('rolling', 'asleep') iwc5jn
# ('shoulders', 'similar') iwc5jn
# ('shoulders', 'ibuprofen') iwc5jn
# ('shoulders', 'concentration') iwc5jn
# ('shoulders', 'preparation:') iwc5jn
# ('shoulders', 'cardinal') iwc5jn
# ('shoulders', 'person') iwc5jn
# ('shoulders', 'codeine') iwc5jn
# ('shoulders', 'wandering') iwc5jn
# ('shoulders', 'social') iwc5jn
# ('shoulders', 'recreationally') iwc5jn
# ('shoulders', 'development') iwc5jn
# ('shoulders', 'research') iwc5jn
# ('shoulders', 'bloodshot') iwc5jn
# ('shoulders', 'asleep') iidqgu
# ('shoulders', 'fingers') iidqgu
# ('shoulders', 'physical') iidqgu
# ('shoulders', 'living') iidqgu
# ('shoulders', 'smoking') iidqgu
# ('shoulders', 'parents') iidqgu
# ('shoulders', 'substance') iidqgu
# ('shoulders', 'cocaine') iidqgu
# ('shoulders', 'sweat') iidqgu
# ('shoulders', 'string') iidqgu
# ('shoulders', 'another') iidqgu
# ('similar', 'ibuprofen') iwc5jn
# ('similar', 'concentration') iwc5jn
# ('similar', 'preparation:') iwc5jn
# ('similar', 'cardinal') iwc5jn
# ('similar', 'person') ev18s6
# ('similar', 'codeine') iwc5jn
# ('similar', 'wandering') iwc5jn
# ('similar', 'social') iwc5jn
# ('similar', 'recreationally') ilwlj0
# ('similar', 'development') iwc5jn
# ('similar', 'research') ilwlj0
# ('similar', 'bloodshot') iwc5jn
# ('similar', 'asleep') iwc5jn
# ('similar', 'environment') ev18s6
# ('similar', 'cocaine') ilwlj0
# ('similar', 'mushroom') ev18s6
# ('similar', 'psilocybin*') ev18s6
# ('similar', 'standard') ev18s6
# ('wandering', 'asleep') iwc5jn
# ('wandering', 'similar') ev18s6
# ('wandering', 'mushroom') ev18s6
# ('wandering', 'psilocybin*') ev18s6
# ('wandering', 'standard') ev18s6
# ('wandering', 'discussion') ev18s6
# ('wandering', 'environment') ev18s6
# ('wandering', 'question') ev18s6
# ('wandering', 'should') ev18s6
# ('wandering', 'religious') ev18s6
# ('wandering', 'alcohol') ev18s6
# ('wandering', 'substances') ev18s6
# ('wandering', 'questions') ev18s6
# ('wandering', 'person') ev18s6
# ('wandering', 'another') ev18s6
# ('social', 'recreationally') iwc5jn
# ('social', 'development') iwc5jn
# ('social', 'research') iwc5jn
# ('social', 'bloodshot') iwc5jn
# ('social', 'asleep') iwc5jn
# ('social', 'smoking') fqqc37
# ('social', 'cannabis') fqqc37
# ('social', 'another') dz5ye5
# ('social', 'tolerance') fqqc37
# ('social', 'substance') dz5ye5
# ('social', 'collected') es0cs8
# ('social', 'substances') es0cs8
# ('social', 'person') es0cs8
# ('social', 'attribute') es0cs8
# ('social', 'adamant') g17ksq
# ('social', 'parents') g17ksq
# ('social', 'minors') g17ksq
# ('social', 'should') g17ksq
# ('recreationally', 'development') iwc5jn
# ('recreationally', 'research') ilwlj0
# ('recreationally', 'bloodshot') iwc5jn
# ('recreationally', 'asleep') gid5ro
# ('recreationally', 'condition') ig6euz
# ('recreationally', 'organization') ig6euz
# ('recreationally', 'recreational') ig6euz
# ('recreationally', 'cocaine') ilwlj0
# ('recreationally', 'distance') gid5ro
# ('recreationally', 'movement') gid5ro
# ('development', 'research') iwc5jn
# ('development', 'bloodshot') iwc5jn
# ('development', 'asleep') iwc5jn
# ('development', 'psychologically') i2k0ab
# ('development', 'recreational') i2k0ab
# ('research', 'bloodshot') iwc5jn
# ('research', 'asleep') iwc5jn
# ('research', 'practice') f94zw0
# ('research', 'recreational') j6oeyi
# ('research', 'technically') j5sywq
# ('bloodshot', 'asleep') iwc5jn
# ('asleep', 'movement') gid5ro
# ('asleep', 'including') dqy24s
# ('asleep', 'membrane') dqy24s
# ('asleep', 'questions') dqy24s
# ('asleep', 'another') dqy24s
# ('asleep', 'university') dqy24s
# ('heroin', 'belongings') i2k0ab
# ('heroin', 'keeping') i2k0ab
# ('heroin', 'injection') i2k0ab
# ('heroin', 'statistically') i2k0ab
# ('heroin', 'blood') i2k0ab
# ('heroin', 'physical') iidqgu
# ('heroin', 'vision') i2k0ab
# ('heroin', 'background') i2k0ab
# ('heroin', 'diacetylmorphine') i2k0ab
# ('heroin', 'production') i2k0ab
# ('heroin', 'morphine') i2k0ab
# ('heroin', "heroin's") i2k0ab
# ('heroin', 'reading') i2k0ab
# ('heroin', 'realization') i2k0ab
# ('heroin', 'survival') i2k0ab
# ('heroin', 'nausea') i2k0ab
# ('heroin', 'jading') i2k0ab
# ('heroin', 'sickness') i2k0ab
# ('heroin', 'congestion') i2k0ab
# ('heroin', 'addiction') i2k0ab
# ('heroin', 'concentration') i2k0ab
# ('heroin', 'compounds') i2k0ab
# ('heroin', 'effect') i2k0ab
# ('heroin', 'diarrhea') i2k0ab
# ('heroin', 'psychological') i2k0ab
# ('heroin', 'sleeping') i2k0ab
# ('heroin', 'person') hehv9f
# ('heroin', "person's") i2k0ab
# ('heroin', 'respiratory') i2k0ab
# ('heroin', 'injuries') i2k0ab
# ('heroin', 'analgesic') i2k0ab
# ('heroin', 'gastrointestinal') i2k0ab
# ('heroin', 'receptors') i2k0ab
# ('heroin', 'sweats') i2k0ab
# ('heroin', 'substance') iidqgu
# ('heroin', 'development') i2k0ab
# ('heroin', 'psychologically') i2k0ab
# ('heroin', 'recreational') i2k0ab
# ('heroin', 'assistance') f9w8eh
# ('heroin', 'personal') hehv9f
# ('heroin', 'relevant)') hehv9f
# ('heroin', 'question') hehv9f
# ('heroin', 'should') hehv9f
# ('heroin', 'coming') hehv9f
# ('heroin', 'affect') hehv9f
# ('heroin', 'shoulders') iidqgu
# ('heroin', 'fingers') iidqgu
# ('heroin', 'living') iidqgu
# ('heroin', 'smoking') ebh2u0
# ('heroin', 'parents') iidqgu
# ('heroin', 'cocaine') iidqgu
# ('heroin', 'sweat') iidqgu
# ('heroin', 'string') iidqgu
# ('heroin', 'another') iidqgu
# ('heroin', 'asleep') iidqgu
# ('heroin', 'ketamine') j2j18k
# ('heroin', 'health') ebh2u0
# ('heroin', 'publication') j2j18k
# ('heroin', 'information') j2j18k
# ('heroin', 'including') j2j18k
# ('heroin', 'reports') j2j18k
# ('heroin', 'benefits') j2j18k
# ('heroin', 'chemicals;') j2j18k
# ('heroin', 'program') j2j18k
# ('heroin', 'projects') j2j18k
# ('heroin', 'substances') j2j18k
# ('heroin', 'millions') ebh2u0
# ('heroin', 'sourcing') ebh2u0
# ('heroin', 'crimes') ebh2u0
# ('heroin', 'killing') ebh2u0
# ('heroin', 'cigarettes') ebh2u0
# ('heroin', 'discriminate') ebh2u0
# ('heroin', 'included') igvysa
# ('heroin', 'tolerance') igvysa
# ('belongings', 'keeping') i2k0ab
# ('belongings', 'injection') i2k0ab
# ('belongings', 'statistically') i2k0ab
# ('belongings', 'blood') i2k0ab
# ('belongings', 'physical') i2k0ab
# ('belongings', 'vision') i2k0ab
# ('belongings', 'background') i2k0ab
# ('belongings', 'diacetylmorphine') i2k0ab
# ('belongings', 'production') i2k0ab
# ('belongings', 'morphine') i2k0ab
# ('belongings', "heroin's") i2k0ab
# ('belongings', 'reading') fa824i
# ('belongings', 'realization') i2k0ab
# ('belongings', 'survival') i2k0ab
# ('belongings', 'nausea') i2k0ab
# ('belongings', 'jading') i2k0ab
# ('belongings', 'sickness') i2k0ab
# ('belongings', 'congestion') i2k0ab
# ('belongings', 'addiction') i2k0ab
# ('belongings', 'concentration') i2k0ab
# ('belongings', 'compounds') i2k0ab
# ('belongings', 'effect') i2k0ab
# ('belongings', 'diarrhea') i2k0ab
# ('belongings', 'psychological') i2k0ab
# ('belongings', 'sleeping') i2k0ab
# ('belongings', 'person') i2k0ab
# ('belongings', "person's") i2k0ab
# ('belongings', 'respiratory') i2k0ab
# ('belongings', 'injuries') i2k0ab
# ('belongings', 'analgesic') i2k0ab
# ('belongings', 'gastrointestinal') i2k0ab
# ('belongings', 'receptors') i2k0ab
# ('belongings', 'sweats') i2k0ab
# ('belongings', 'substance') i2k0ab
# ('belongings', 'development') i2k0ab
# ('belongings', 'psychologically') i2k0ab
# ('belongings', 'recreational') i2k0ab
# ('belongings', 'better') fa824i
# ('belongings', 'coming') fa824i
# ('belongings', 'turkey') fa824i
# ('belongings', 'surgery') fa824i
# ('belongings', 'discriminate') fa824i
# ('statistically', 'blood') i2k0ab
# ('statistically', 'physical') i2k0ab
# ('statistically', 'vision') i2k0ab
# ('statistically', 'background') i2k0ab
# ('statistically', 'diacetylmorphine') i2k0ab
# ('statistically', 'production') i2k0ab
# ('statistically', 'morphine') i2k0ab
# ('statistically', "heroin's") i2k0ab
# ('statistically', 'reading') i2k0ab
# ('statistically', 'realization') i2k0ab
# ('statistically', 'survival') i2k0ab
# ('statistically', 'nausea') i2k0ab
# ('statistically', 'jading') i2k0ab
# ('statistically', 'sickness') i2k0ab
# ('statistically', 'congestion') i2k0ab
# ('statistically', 'addiction') i2k0ab
# ('statistically', 'concentration') i2k0ab
# ('statistically', 'compounds') i2k0ab
# ('statistically', 'effect') i2k0ab
# ('statistically', 'diarrhea') i2k0ab
# ('statistically', 'psychological') i2k0ab
# ('statistically', 'sleeping') i2k0ab
# ('statistically', 'person') i2k0ab
# ('statistically', "person's") i2k0ab
# ('statistically', 'respiratory') i2k0ab
# ('statistically', 'injuries') i2k0ab
# ('statistically', 'analgesic') i2k0ab
# ('statistically', 'gastrointestinal') i2k0ab
# ('statistically', 'receptors') i2k0ab
# ('statistically', 'sweats') i2k0ab
# ('statistically', 'substance') i2k0ab
# ('statistically', 'development') i2k0ab
# ('statistically', 'psychologically') i2k0ab
# ('statistically', 'recreational') i2k0ab
# ('blood', 'physical') i2k0ab
# ('blood', 'vision') i2k0ab
# ('blood', 'background') i2k0ab
# ('blood', 'diacetylmorphine') i2k0ab
# ('blood', 'production') i2k0ab
# ('blood', 'morphine') i2k0ab
# ('blood', "heroin's") i2k0ab
# ('blood', 'reading') i2k0ab
# ('blood', 'realization') i2k0ab
# ('blood', 'survival') i2k0ab
# ('blood', 'nausea') i2k0ab
# ('blood', 'jading') i2k0ab
# ('blood', 'sickness') i2k0ab
# ('blood', 'congestion') i2k0ab
# ('blood', 'addiction') i2k0ab
# ('blood', 'concentration') i2k0ab
# ('blood', 'compounds') i2k0ab
# ('blood', 'effect') i2k0ab
# ('blood', 'diarrhea') i2k0ab
# ('blood', 'psychological') i2k0ab
# ('blood', 'sleeping') i2k0ab
# ('blood', 'person') i2k0ab
# ('blood', "person's") i2k0ab
# ('blood', 'respiratory') i2k0ab
# ('blood', 'injuries') i2k0ab
# ('blood', 'analgesic') i2k0ab
# ('blood', 'gastrointestinal') i2k0ab
# ('blood', 'receptors') i2k0ab
# ('blood', 'sweats') i2k0ab
# ('blood', 'substance') i2k0ab
# ('blood', 'development') i2k0ab
# ('blood', 'psychologically') i2k0ab
# ('blood', 'recreational') i2k0ab
# ('blood', 'asleep') e427qz
# ('physical', 'vision') i2k0ab
# ('physical', 'background') i2k0ab
# ('physical', 'diacetylmorphine') i2k0ab
# ('physical', 'production') i2k0ab
# ('physical', 'morphine') i2k0ab
# ('physical', "heroin's") i2k0ab
# ('physical', 'reading') etxns5
# ('physical', 'realization') i2k0ab
# ('physical', 'survival') i2k0ab
# ('physical', 'nausea') gmcq4n
# ('physical', 'jading') i2k0ab
# ('physical', 'sickness') i2k0ab
# ('physical', 'congestion') i2k0ab
# ('physical', 'addiction') i2k0ab
# ('physical', 'concentration') i2k0ab
# ('physical', 'compounds') i2k0ab
# ('physical', 'effect') i2k0ab
# ('physical', 'diarrhea') i2k0ab
# ('physical', 'psychological') i2k0ab
# ('physical', 'sleeping') i2k0ab
# ('physical', 'person') i2k0ab
# ('physical', "person's") i2k0ab
# ('physical', 'respiratory') i2k0ab
# ('physical', 'injuries') i2k0ab
# ('physical', 'analgesic') i2k0ab
# ('physical', 'gastrointestinal') i2k0ab
# ('physical', 'receptors') i2k0ab
# ('physical', 'sweats') i2k0ab
# ('physical', 'substance') iidqgu
# ('physical', 'development') i2k0ab
# ('physical', 'psychologically') i2k0ab
# ('physical', 'recreational') i2k0ab
# ('physical', 'schizophrenic') etxns5
# ('physical', 'tremors') etxns5
# ('physical', 'better') etxns5
# ('physical', 'marijuana') etxns5
# ('physical', 'morality') etxns5
# ('physical', 'living') iidqgu
# ('physical', 'smoking') iidqgu
# ('physical', 'parents') iidqgu
# ('physical', 'cocaine') iidqgu
# ('physical', 'sweat') iidqgu
# ('physical', 'string') iidqgu
# ('physical', 'another') iidqgu
# ('physical', 'asleep') iidqgu
# ('physical', 'activity') gmcq4n
# ('vision', 'background') i2k0ab
# ('vision', 'diacetylmorphine') i2k0ab
# ('vision', 'production') i2k0ab
# ('vision', 'morphine') i2k0ab
# ('vision', "heroin's") i2k0ab
# ('vision', 'reading') i2k0ab
# ('vision', 'realization') i2k0ab
# ('vision', 'survival') i2k0ab
# ('vision', 'nausea') hws52w
# ('vision', 'jading') i2k0ab
# ('vision', 'sickness') i2k0ab
# ('vision', 'congestion') i2k0ab
# ('vision', 'addiction') i2k0ab
# ('vision', 'concentration') i2k0ab
# ('vision', 'compounds') i2k0ab
# ('vision', 'effect') i2k0ab
# ('vision', 'diarrhea') i2k0ab
# ('vision', 'psychological') i2k0ab
# ('vision', 'sleeping') i2k0ab
# ('vision', 'person') i2k0ab
# ('vision', "person's") i2k0ab
# ('vision', 'respiratory') i2k0ab
# ('vision', 'injuries') i2k0ab
# ('vision', 'analgesic') i2k0ab
# ('vision', 'gastrointestinal') i2k0ab
# ('vision', 'receptors') i2k0ab
# ('vision', 'sweats') i2k0ab
# ('vision', 'substance') i2k0ab
# ('vision', 'development') i2k0ab
# ('vision', 'psychologically') i2k0ab
# ('vision', 'recreational') i2k0ab
# ('vision', 'suggestability') hws52w
# ('vision', 'living') e2hanq
# ('vision', 'lifting') hws52w
# ('vision', 'expericing') hws52w
# ('vision', 'sweat') hws52w
# ('vision', 'coppers') hws52w
# ('vision', 'sleep"') hws52w
# ('vision', 'substances') hws52w
# ('vision', '(blood') e2hanq
# ('vision', 'parents') e2hanq
# ('vision', 'should') e2hanq
# ('vision', 'coming') e2hanq
# ('vision', 'morale') e2hanq
# ('vision', 'temperature') e2hanq
# ('vision', 'imagination') e2hanq
# ('vision', 'pupils') e2hanq
# ('vision', 'question') e2hanq
# ('vision', 'another') jagrpk
# ('vision', 'perception') jagrpk
# ('vision', 'movements') jagrpk
# ('vision', 'earthquake') jagrpk
# ('diacetylmorphine', 'production') i2k0ab
# ('diacetylmorphine', 'morphine') i2k0ab
# ('diacetylmorphine', "heroin's") i2k0ab
# ('diacetylmorphine', 'reading') i2k0ab
# ('diacetylmorphine', 'realization') i2k0ab
# ('diacetylmorphine', 'survival') i2k0ab
# ('diacetylmorphine', 'nausea') i2k0ab
# ('diacetylmorphine', 'jading') i2k0ab
# ('diacetylmorphine', 'sickness') i2k0ab
# ('diacetylmorphine', 'congestion') i2k0ab
# ('diacetylmorphine', 'addiction') i2k0ab
# ('diacetylmorphine', 'concentration') i2k0ab
# ('diacetylmorphine', 'compounds') i2k0ab
# ('diacetylmorphine', 'effect') i2k0ab
# ('diacetylmorphine', 'diarrhea') i2k0ab
# ('diacetylmorphine', 'psychological') i2k0ab
# ('diacetylmorphine', 'sleeping') i2k0ab
# ('diacetylmorphine', 'person') i2k0ab
# ('diacetylmorphine', "person's") i2k0ab
# ('diacetylmorphine', 'respiratory') i2k0ab
# ('diacetylmorphine', 'injuries') i2k0ab
# ('diacetylmorphine', 'analgesic') i2k0ab
# ('diacetylmorphine', 'gastrointestinal') i2k0ab
# ('diacetylmorphine', 'receptors') i2k0ab
# ('diacetylmorphine', 'sweats') i2k0ab
# ('diacetylmorphine', 'substance') i2k0ab
# ('diacetylmorphine', 'development') i2k0ab
# ('diacetylmorphine', 'psychologically') i2k0ab
# ('diacetylmorphine', 'recreational') i2k0ab
# ('production', 'morphine') i2k0ab
# ('production', "heroin's") i2k0ab
# ('production', 'reading') i2k0ab
# ('production', 'realization') i2k0ab
# ('production', 'survival') i2k0ab
# ('production', 'nausea') i2k0ab
# ('production', 'jading') i2k0ab
# ('production', 'sickness') i2k0ab
# ('production', 'congestion') i2k0ab
# ('production', 'addiction') i2k0ab
# ('production', 'concentration') i2k0ab
# ('production', 'compounds') i2k0ab
# ('production', 'effect') i2k0ab
# ('production', 'diarrhea') i2k0ab
# ('production', 'psychological') i2k0ab
# ('production', 'sleeping') i2k0ab
# ('production', 'person') i2k0ab
# ('production', "person's") i2k0ab
# ('production', 'respiratory') i2k0ab
# ('production', 'injuries') i2k0ab
# ('production', 'analgesic') i2k0ab
# ('production', 'gastrointestinal') i2k0ab
# ('production', 'receptors') i2k0ab
# ('production', 'sweats') i2k0ab
# ('production', 'substance') i2k0ab
# ('production', 'development') i2k0ab
# ('production', 'psychologically') i2k0ab
# ('production', 'recreational') i2k0ab
# ('morphine', "heroin's") i2k0ab
# ('morphine', 'reading') i2k0ab
# ('morphine', 'realization') i2k0ab
# ('morphine', 'survival') i2k0ab
# ('morphine', 'nausea') i2k0ab
# ('morphine', 'jading') i2k0ab
# ('morphine', 'sickness') i2k0ab
# ('morphine', 'congestion') i2k0ab
# ('morphine', 'addiction') i2k0ab
# ('morphine', 'concentration') i2k0ab
# ('morphine', 'compounds') i2k0ab
# ('morphine', 'effect') i2k0ab
# ('morphine', 'diarrhea') i2k0ab
# ('morphine', 'psychological') i2k0ab
# ('morphine', 'sleeping') i2k0ab
# ('morphine', 'person') i2k0ab
# ('morphine', "person's") i2k0ab
# ('morphine', 'respiratory') i2k0ab
# ('morphine', 'injuries') i2k0ab
# ('morphine', 'analgesic') i2k0ab
# ('morphine', 'gastrointestinal') i2k0ab
# ('morphine', 'receptors') i2k0ab
# ('morphine', 'sweats') i2k0ab
# ('morphine', 'substance') i2k0ab
# ('morphine', 'development') i2k0ab
# ('morphine', 'psychologically') i2k0ab
# ('morphine', 'recreational') i2k0ab
# ("heroin's", 'reading') i2k0ab
# ("heroin's", 'realization') i2k0ab
# ("heroin's", 'survival') i2k0ab
# ("heroin's", 'nausea') i2k0ab
# ("heroin's", 'jading') i2k0ab
# ("heroin's", 'sickness') i2k0ab
# ("heroin's", 'congestion') i2k0ab
# ("heroin's", 'addiction') i2k0ab
# ("heroin's", 'concentration') i2k0ab
# ("heroin's", 'compounds') i2k0ab
# ("heroin's", 'effect') i2k0ab
# ("heroin's", 'diarrhea') i2k0ab
# ("heroin's", 'psychological') i2k0ab
# ("heroin's", 'sleeping') i2k0ab
# ("heroin's", 'person') i2k0ab
# ("heroin's", "person's") i2k0ab
# ("heroin's", 'respiratory') i2k0ab
# ("heroin's", 'injuries') i2k0ab
# ("heroin's", 'analgesic') i2k0ab
# ("heroin's", 'gastrointestinal') i2k0ab
# ("heroin's", 'receptors') i2k0ab
# ("heroin's", 'sweats') i2k0ab
# ("heroin's", 'substance') i2k0ab
# ("heroin's", 'development') i2k0ab
# ("heroin's", 'psychologically') i2k0ab
# ("heroin's", 'recreational') i2k0ab
# ('reading', 'realization') i2k0ab
# ('reading', 'survival') i2k0ab
# ('reading', 'nausea') gid5ro
# ('reading', 'jading') i2k0ab
# ('reading', 'sickness') i2k0ab
# ('reading', 'congestion') i2k0ab
# ('reading', 'addiction') evijgu
# ('reading', 'concentration') i2k0ab
# ('reading', 'compounds') i2k0ab
# ('reading', 'effect') gid5ro
# ('reading', 'diarrhea') gid5ro
# ('reading', 'psychological') i2k0ab
# ('reading', 'sleeping') i2k0ab
# ('reading', 'person') i2k0ab
# ('reading', "person's") i2k0ab
# ('reading', 'respiratory') i2k0ab
# ('reading', 'injuries') i2k0ab
# ('reading', 'analgesic') i2k0ab
# ('reading', 'gastrointestinal') i2k0ab
# ('reading', 'receptors') i2k0ab
# ('reading', 'sweats') i2k0ab
# ('reading', 'substance') i2k0ab
# ('reading', 'development') i2k0ab
# ('reading', 'psychologically') i2k0ab
# ('reading', 'recreational') i2k0ab
# ('reading', 'nicotine') gid5ro
# ('reading', 'adduction') j3htdm
# ('reading', 'turkey') fa824i
# ('reading', 'surgery') fa824i
# ('reading', 'discriminate') fa824i
# ('reading', 'caffeine') gid5ro
# ('reading', 'extraction') gid5ro
# ('reading', 'alcohol)') gid5ro
# ('reading', 'included') hwfof8
# ('reading', 'smoking') gid5ro
# ('reading', 'cocaine') gid5ro
# ('reading', 'improve') gid5ro
# ('reading', 'recreationally') gid5ro
# ('reading', 'distance') gid5ro
# ('reading', 'asleep') gid5ro
# ('reading', 'movement') gid5ro
# ('reading', 'marijuana') etxns5
# ('reading', 'morality') etxns5
# ('reading', 'classes') hwfof8
# ('reading', 'cannabis') evijgu
# ('reading', 'addiction!') evijgu
# ('realization', 'survival') i2k0ab
# ('realization', 'nausea') i2k0ab
# ('realization', 'jading') i2k0ab
# ('realization', 'sickness') i2k0ab
# ('realization', 'congestion') i2k0ab
# ('realization', 'addiction') i2k0ab
# ('realization', 'concentration') i2k0ab
# ('realization', 'compounds') i2k0ab
# ('realization', 'effect') i2k0ab
# ('realization', 'diarrhea') i2k0ab
# ('realization', 'psychological') i2k0ab
# ('realization', 'sleeping') i2k0ab
# ('realization', 'person') i2k0ab
# ('realization', "person's") i2k0ab
# ('realization', 'respiratory') i2k0ab
# ('realization', 'injuries') i2k0ab
# ('realization', 'analgesic') i2k0ab
# ('realization', 'gastrointestinal') i2k0ab
# ('realization', 'receptors') i2k0ab
# ('realization', 'sweats') i2k0ab
# ('realization', 'substance') i2k0ab
# ('realization', 'development') i2k0ab
# ('realization', 'psychologically') i2k0ab
# ('realization', 'recreational') i2k0ab
# ('realization', '\\*stereotypical') dti8sq
# ('realization', 'german') dti8sq
# ('realization', 'including') dti8sq
# ('realization', 'reports') dti8sq
# ('realization', 'combination') dti8sq
# ('realization', 'platinum') dti8sq
# ('realization', 'mention') dti8sq
# ('realization', 'alcohol') dti8sq
# ('realization', 'caffeine') dti8sq
# ('realization', 'contain') dti8sq
# ('realization', 'mentions') dti8sq
# ('survival', 'nausea') i2k0ab
# ('survival', 'jading') i2k0ab
# ('survival', 'sickness') i2k0ab
# ('survival', 'congestion') i2k0ab
# ('survival', 'addiction') i2k0ab
# ('survival', 'concentration') i2k0ab
# ('survival', 'compounds') i2k0ab
# ('survival', 'effect') i2k0ab
# ('survival', 'diarrhea') i2k0ab
# ('survival', 'psychological') i2k0ab
# ('survival', 'sleeping') i2k0ab
# ('survival', 'person') i2k0ab
# ('survival', "person's") i2k0ab
# ('survival', 'respiratory') i2k0ab
# ('survival', 'injuries') i2k0ab
# ('survival', 'analgesic') i2k0ab
# ('survival', 'gastrointestinal') i2k0ab
# ('survival', 'receptors') i2k0ab
# ('survival', 'sweats') i2k0ab
# ('survival', 'substance') i2k0ab
# ('survival', 'development') i2k0ab
# ('survival', 'psychologically') i2k0ab
# ('survival', 'recreational') i2k0ab
# ('nausea', 'jading') i2k0ab
# ('nausea', 'sickness') i2k0ab
# ('nausea', 'congestion') i2k0ab
# ('nausea', 'addiction') i2k0ab
# ('nausea', 'concentration') i2k0ab
# ('nausea', 'compounds') i2k0ab
# ('nausea', 'effect') gid5ro
# ('nausea', 'diarrhea') gid5ro
# ('nausea', 'psychological') i2k0ab
# ('nausea', 'sleeping') i2k0ab
# ('nausea', 'person') i2k0ab
# ('effect', 'relaxation') dz5ye5
# ('effect', 'social') dz5ye5
# ('effect', 'another') dz5ye5
# ('effect', 'nicotine') gid5ro
# ('effect', 'improve') gid5ro
# ('effect', 'recreationally') gid5ro
# ('effect', 'distance') gid5ro
# ('effect', 'asleep') gid5ro
# ('effect', 'movement') gid5ro
# ...
# ('efficiency', 'effect') dv5gy3
# ('efficiency', 'biological') dv5gy3
# ('efficiency', 'person') dv5gy3
# ('efficiency', 'university') dv5gy3
# ('creating', 'pharmacy') dv5gy3
# ('creating', 'prescription') dv5gy3
# ('creating', 'effect') dv5gy3
# ('creating', 'biological') dv5gy3
# ('creating', 'person') dv5gy3
# ('creating', 'university') dv5gy3
# ('pharmacy', 'prescription') dv5gy3
# ('pharmacy', 'effect') dv5gy3
# ('pharmacy', 'biological') dv5gy3
# ('pharmacy', 'person') dv5gy3
# ('pharmacy', 'university') dv5gy3
# ('prescription', 'effect') dv5gy3
# ('prescription', 'biological') dv5gy3
# ('prescription', 'person') dv5gy3
# ('prescription', 'university') dv5gy3
# ('biological', 'person') dv5gy3
# ('biological', 'university') dv5gy3
# ('shifting', 'alcohol') dz5ye5
# ('shifting', 'popular') dz5ye5
# ('shifting', 'chemical') dz5ye5
# ('shifting', 'should') dz5ye5
# ('shifting', 'caffeine') dz5ye5
# ('shifting', 'salvia') dz5ye5
# ('shifting', 'animals') dz5ye5
# ('shifting', 'condition') dz5ye5
# ('shifting', 'smokers') dz5ye5
# ('shifting', 'pretend') dz5ye5
# ('shifting', 'effect') dz5ye5
# ('shifting', 'consciousness') dz5ye5
# ('shifting', 'relaxation') dz5ye5
# ('shifting', 'social') dz5ye5
# ('shifting', 'substance') dz5ye5
# ('shifting', 'another') dz5ye5
# ('popular', 'chemical') dz5ye5
# ('popular', 'should') dz5ye5
# ('popular', 'caffeine') dz5ye5
# ('popular', 'salvia') dz5ye5
# ('popular', 'animals') dz5ye5
# ('popular', 'condition') dz5ye5
# ('popular', 'smokers') dz5ye5
# ('popular', 'pretend') dz5ye5
# ('popular', 'effect') dz5ye5
# ('popular', 'consciousness') dz5ye5
# ('popular', 'relaxation') dz5ye5
# ('popular', 'social') dz5ye5
# ('popular', 'substance') dz5ye5
# ('popular', 'another') dz5ye5
# ('salvia', 'animals') dz5ye5
# ('salvia', 'condition') dz5ye5
# ('salvia', 'smokers') dz5ye5
# ('salvia', 'pretend') dz5ye5
# ('salvia', 'effect') dz5ye5
# ('salvia', 'consciousness') dz5ye5
# ('salvia', 'relaxation') dz5ye5
# ('salvia', 'social') dz5ye5
# ('salvia', 'substance') dz5ye5
# ('salvia', 'another') dz5ye5
# ('animals', 'condition') dz5ye5
# ('animals', 'smokers') dz5ye5
# ('animals', 'pretend') dz5ye5
# ('animals', 'effect') dz5ye5
# ('animals', 'consciousness') dz5ye5
# ('animals', 'relaxation') dz5ye5
# ('animals', 'social') dz5ye5
# ('animals', 'substance') dz5ye5
# ('animals', 'another') dz5ye5
# ('animals', 'practitioner') e3dwnz
# ('animals', 'relating') e3dwnz
# ('animals', 'invitation') e3dwnz
# ('smokers', 'pretend') dz5ye5
# ('smokers', 'effect') dz5ye5
# ('smokers', 'consciousness') dz5ye5
# ('smokers', 'relaxation') dz5ye5
# ('smokers', 'social') dz5ye5
# ('smokers', 'substance') dz5ye5
# ('smokers', 'another') dz5ye5
# ('consciousness', 'relaxation') dz5ye5
# ('consciousness', 'social') dz5ye5
# ('consciousness', 'substance') dz5ye5
# ('consciousness', 'another') dz5ye5
# ('relaxation', 'social') dz5ye5
# ('relaxation', 'substance') dz5ye5
# ('relaxation', 'another') dz5ye5
# ('mushroom', 'psilocybin*') ev18s6
# ('mushroom', 'standard') ev18s6
# ('mushroom', 'discussion') ev18s6
# ('mushroom', 'environment') ev18s6
# ('mushroom', 'question') ev18s6
# ('mushroom', 'should') ev18s6
# ('mushroom', 'religious') ev18s6
# ('mushroom', 'alcohol') ev18s6
# ('mushroom', 'substances') ev18s6
# ('mushroom', 'questions') ev18s6
# ('mushroom', 'person') ev18s6
# ('mushroom', 'another') ev18s6
# ('psilocybin*', 'standard') ev18s6
# ('psilocybin*', 'discussion') ev18s6
# ('psilocybin*', 'environment') ev18s6
# ('psilocybin*', 'question') ev18s6
# ('psilocybin*', 'should') ev18s6
# ('psilocybin*', 'religious') ev18s6
# ('psilocybin*', 'alcohol') ev18s6
# ('psilocybin*', 'substances') ev18s6
# ('psilocybin*', 'questions') ev18s6
# ('psilocybin*', 'person') ev18s6
# ('psilocybin*', 'another') ev18s6
# ('standard', 'discussion') ev18s6
# ('standard', 'environment') ev18s6
# ('standard', 'question') e2hanq
# ('standard', 'should') e2hanq
# ('standard', 'religious') ev18s6
# ('standard', 'alcohol') ev18s6
# ('standard', 'substances') ev18s6
# ('standard', 'questions') ev18s6
# ('standard', 'person') ev18s6
# ('standard', 'another') e2hanq
# ('standard', 'vision') e2hanq
# ('standard', '(blood') e2hanq
# ('standard', 'living') e2hanq
# ('standard', 'parents') e2hanq
# ('standard', 'coming') e2hanq
# ('standard', 'morale') e2hanq
# ('standard', 'temperature') e2hanq
# ('standard', 'imagination') e2hanq
# ('standard', 'pupils') e2hanq
# ('discussion', 'environment') ev18s6
# ('discussion', 'question') j5sywq
# ('discussion', 'should') j5sywq
# ('discussion', 'religious') ev18s6
# ('discussion', 'alcohol') ev18s6
# ('discussion', 'substances') ev18s6
# ('discussion', 'questions') j5sywq
# ('discussion', 'person') ev18s6
# ('discussion', 'another') ev18s6
# ('discussion', 'substance') j5sywq
# ('discussion', 'spreading') j5sywq
# ('discussion', 'research') j5sywq
# ('discussion', 'technically') j5sywq
# ('religious', 'alcohol') ev18s6
# ('religious', 'substances') ev18s6
# ('religious', 'questions') ev18s6
# ('religious', 'person') ev18s6
# ('religious', 'another') ev18s6
# ('personal', 'addiction') fa824i
# ('personal', 'belongings') fa824i
# ('personal', 'better') fa824i
# ('personal', 'coming') hehv9f
# ('personal', 'reading') gid5ro
# ('personal', 'turkey') fa824i
# ('personal', 'surgery') fa824i
# ('personal', 'discriminate') fa824i
# ('personal', 'relevant)') hehv9f
# ('personal', 'question') hehv9f
# ('extraction', 'effect') gid5ro
# ('extraction', 'diarrhea') gid5ro
# ('extraction', 'nicotine') gid5ro
# ('extraction', 'improve') gid5ro
# ('extraction', 'recreationally') gid5ro
# ('extraction', 'distance') gid5ro
# ('extraction', 'asleep') gid5ro
# ('extraction', 'movement') gid5ro
# ('alcohol)', 'included') gid5ro
# ('alcohol)', 'smoking') gid5ro
# ('alcohol)', 'cocaine') gid5ro
# ('alcohol)', 'effect') gid5ro
# ('alcohol)', 'diarrhea') gid5ro
# ('alcohol)', 'nicotine') gid5ro
# ('alcohol)', 'improve') gid5ro
# ('alcohol)', 'recreationally') gid5ro
# ('alcohol)', 'distance') gid5ro
# ('alcohol)', 'asleep') gid5ro
# ('alcohol)', 'movement') gid5ro
# ('improve', 'recreationally') gid5ro
# ('improve', 'distance') gid5ro
# ('improve', 'asleep') gid5ro
# ('improve', 'movement') gid5ro
# ('distance', 'asleep') gid5ro
# ('distance', 'movement') gid5ro
# ('fingers', 'classes') ev9s9x
# ('fingers', 'background') ev9s9x
# ('fingers', 'information') ev9s9x
# ('fingers', 'communication') ev9s9x
# ('fingers', 'living') iidqgu
# ('fingers', 'smoking') iidqgu
# ('fingers', 'thefts') ev9s9x
# ('fingers', 'better') ev9s9x
# ('fingers', 'coming') ev9s9x
# ('fingers', 'nicotine') ev9s9x
# ('fingers', 'security') ev9s9x
# ('fingers', 'solution') ev9s9x
# ('fingers', 'person') ev9s9x
# ('fingers', 'another') iidqgu
# ('fingers', 'physical') iidqgu
# ('fingers', 'parents') iidqgu
# ('fingers', 'substance') iidqgu
# ('fingers', 'cocaine') iidqgu
# ('fingers', 'sweat') iidqgu
# ('fingers', 'string') iidqgu
# ('fingers', 'asleep') iidqgu
# ('communication', 'living') ev9s9x
# ('communication', 'smoking') ev9s9x
# ('communication', 'thefts') ev9s9x
# ('communication', 'better') ev9s9x
# ('communication', 'coming') ev9s9x
# ('communication', 'nicotine') ev9s9x
# ('communication', 'security') ev9s9x
# ('communication', 'solution') ev9s9x
# ('communication', 'person') ev9s9x
# ('communication', 'another') ev9s9x
# ('thefts', 'better') ev9s9x
# ('thefts', 'coming') ev9s9x
# ('thefts', 'nicotine') ev9s9x
# ('thefts', 'security') ev9s9x
# ('thefts', 'solution') ev9s9x
# ('thefts', 'person') ev9s9x
# ('thefts', 'another') ev9s9x
# ('security', 'solution') ev9s9x
# ('security', 'person') ev9s9x
# ('security', 'another') ev9s9x
# ('solution', 'person') ev9s9x
# ('solution', 'another') ev9s9x
# ('logical', 'pressure)') e2hanq
# ('logical', 'standard') e2hanq
# ('logical', 'vision') e2hanq
# ('logical', '(blood') e2hanq
# ('logical', 'living') e2hanq
# ('logical', 'parents') e2hanq
# ('logical', 'should') e2hanq
# ('logical', 'coming') e2hanq
# ('logical', 'morale') e2hanq
# ('logical', 'temperature') e2hanq
# ('logical', 'imagination') e2hanq
# ('logical', 'pupils') e2hanq
# ('logical', 'question') e2hanq
# ('logical', 'another') e2hanq
# ('pressure)', 'standard') e2hanq
# ('pressure)', 'vision') e2hanq
# ('pressure)', '(blood') e2hanq
# ('pressure)', 'living') e2hanq
# ('pressure)', 'parents') e2hanq
# ('pressure)', 'should') e2hanq
# ('pressure)', 'coming') e2hanq
# ('pressure)', 'morale') e2hanq
# ('pressure)', 'temperature') e2hanq
# ('pressure)', 'imagination') e2hanq
# ('pressure)', 'pupils') e2hanq
# ('pressure)', 'question') e2hanq
# ('pressure)', 'another') e2hanq
# ('(blood', 'living') e2hanq
# ('(blood', 'parents') e2hanq
# ('(blood', 'should') e2hanq
# ('(blood', 'coming') e2hanq
# ('(blood', 'morale') e2hanq
# ('(blood', 'temperature') e2hanq
# ('(blood', 'imagination') e2hanq
# ('(blood', 'pupils') e2hanq
# ('(blood', 'question') e2hanq
# ('(blood', 'another') e2hanq
# ('morale', 'temperature') e2hanq
# ('morale', 'imagination') e2hanq
# ('morale', 'pupils') e2hanq
# ('morale', 'question') e2hanq
# ('morale', 'another') e2hanq
# ('imagination', 'pupils') e2hanq
# ('imagination', 'question') e2hanq
# ('imagination', 'another') e2hanq
# ('schizophrenic', 'tremors') etxns5
# ('schizophrenic', 'better') etxns5
# ('schizophrenic', 'reading') etxns5
# ('schizophrenic', 'marijuana') etxns5
# ('schizophrenic', 'morality') etxns5
# ('tremors', 'better') etxns5
# ('tremors', 'reading') etxns5
# ('tremors', 'marijuana') etxns5
# ('tremors', 'morality') etxns5
# ('addressed', 'government') fiyz0u
# ('addressed', 'smoking') fiyz0u
# ('disclosure:', 'pleading') g17ksq
# ('disclosure:', 'address') g17ksq
# ('disclosure:', 'social') g17ksq
# ('disclosure:', 'adamant') g17ksq
# ('disclosure:', 'parents') g17ksq
# ('disclosure:', 'minors') g17ksq
# ('disclosure:', 'should') g17ksq
# ('pleading', 'address') g17ksq
# ('pleading', 'social') g17ksq
# ('pleading', 'adamant') g17ksq
# ('pleading', 'parents') g17ksq
# ('pleading', 'minors') g17ksq
# ('pleading', 'should') g17ksq
# ('address', 'social') g17ksq
# ('address', 'adamant') g17ksq
# ('address', 'parents') g17ksq
# ('address', 'minors') g17ksq
# ('address', 'should') g17ksq
# ('adamant', 'parents') g17ksq
# ('adamant', 'minors') g17ksq
# ('adamant', 'should') g17ksq
# ('minors', 'should') g17ksq
# ('string', 'another') iidqgu
# ('string', 'asleep') iidqgu
# ('membrane', 'questions') dqy24s
# ('membrane', 'another') dqy24s
# ('membrane', 'university') dqy24s
# ('perception', 'movements') jagrpk
# ('perception', 'earthquake') jagrpk
# ('perception', 'another') jagrpk
# ('movements', 'earthquake') jagrpk
# ('movements', 'another') jagrpk
# ('earthquake', 'another') jagrpk
# ('colorado', 'acting') ed8czl
# ('colorado', 'health') ed8czl
# ('acting', 'health') ed8czl
# ('publication', 'information') j2j18k
# ('publication', 'including') j2j18k
# ('publication', 'reports') j2j18k
# ('publication', 'benefits') j2j18k
# ('publication', 'chemicals;') j2j18k
# ('publication', 'program') j2j18k
# ('publication', 'projects') j2j18k
# ('publication', 'substances') j2j18k
# ('publication', 'millions') j2j18k
# ('benefits', 'chemicals;') j2j18k
# ('benefits', 'program') j2j18k
# ('benefits', 'projects') j2j18k
